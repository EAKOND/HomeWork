# %%
import requests
import pandas as pd
import pickle 
offset_ = 1000
limit_ = 4000
url = f'https://xn--80az8a.xn--d1aqf.xn--p1ai/%D1%81%D0%B5%D1%80%D0%B2%D0%B8%D1%81%D1%8B/api/kn/object?offset=1000&limit=7000&sortField=.devShortCleanNm&sortType=asc&objStatus=0'
res = requests.get(url)
objects_data = res.json()
objects_data.get('data').get('list')[0]
other_list = sorted('list')
objects_list = objects_data.get('data').get('list')
objids = [x.get('objId') for x in objects_list]
objids[:10]
res = requests.get(url)
res.json()
x = res.json()['data']['list']
df = pd.DataFrame.from_dict(x, orient='columns')
print(df)
df.to_csv('file.csv')
with open('test_pickle.pkl', 'wb') as pickle_out:
    pickle.dump(df, pickle_out)
# Out:
#       hobjId  objId                                          developer  \
# 0      33544  25683  {'devId': 6723, 'shortName': 'МОНОЛИТ-СТРОЙ', ...
# 1      23418  25801  {'devId': 6449, 'shortName': 'СЗ СПЕКТР ЛК', '...
# 2      23413  25802  {'devId': 6449, 'shortName': 'СЗ СПЕКТР ЛК', '...
# 3      33147  25805  {'devId': 6723, 'shortName': 'МОНОЛИТ-СТРОЙ', ...
# 4      33720  25808  {'devId': 6723, 'shortName': 'МОНОЛИТ-СТРОЙ', ...
# ...      ...    ...                                                ...
# 6995  127192  46561  {'devId': 13486, 'shortName': 'СЗ ЭКОСТРОЙ', '...
# 6996  127193  46562  {'devId': 3277, 'shortName': 'СМПФ ЭЛРИ', 'ful...
# 6997  127194  46563  {'devId': 14056, 'shortName': 'СЗ СПБ РЕНОВАЦИ...
# 6998  127195  46564  {'devId': 13946, 'shortName': 'СЗ ВЕРШИНА', 'f...
# 6999  127196  46565  {'devId': 2469, 'shortName': 'СЗ СК СТРОЙВИКТО...
#
#       rpdRegionCd                                            objAddr  \
# ...
