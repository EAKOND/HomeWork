# %%
import requests
import pandas as pd
import pickle 
import sqlite3
#offset_ = 1000
#limit_ = 4000
url = f'https://xn--80az8a.xn--d1aqf.xn--p1ai/%D1%81%D0%B5%D1%80%D0%B2%D0%B8%D1%81%D1%8B/api/kn/object?offset=10&limit=5000&sortField=.devShortCleanNm&sortType=asc&objStatus=0'
res = requests.get(url)
objects_data = res.json()
objects_data.get('data').get('list')[0]
objects_list = objects_data.get('data').get('list')
objids = [x.get('objId') for x in objects_list]
objids[:10]
res = requests.get(url)
res.json()
x = res.json()['data']['list']
df = pd.DataFrame.from_dict(x, orient='columns')
df
# Out:
#       hobjId  objId                                          developer  \
# 0       9709   1527  {'devId': 992, 'shortName': 'ИСК', 'fullName':...
# 1      11940   1804  {'devId': 784, 'shortName': 'СЗ ВОСТОК', 'full...
# 2      11753   1805  {'devId': 784, 'shortName': 'СЗ ВОСТОК', 'full...
# 3      18507   1816  {'devId': 281, 'shortName': 'СК КВАРТАЛ', 'ful...
# 4      10590   1817  {'devId': 281, 'shortName': 'СК КВАРТАЛ', 'ful...
# ...      ...    ...                                                ...
# 4995  123260  42685  {'devId': 1074, 'shortName': 'СЗ ЭВРИКА', 'ful...
# 4996  123261  42686  {'devId': 1074, 'shortName': 'СЗ ЭВРИКА', 'ful...
# 4997  123262  42687  {'devId': 12625, 'shortName': 'СЗ ДСК-1', 'ful...
# 4998  123271  42696  {'devId': 13196, 'shortName': 'СТРОИТЕЛЬНАЯ КО...
# 4999  123272  42697  {'devId': 3049, 'shortName': 'СЗ СФЕРА', 'full...
#
#       rpdRegionCd                                            objAddr  \
# ...

# %%
#df.to_csv('file.csv')

# %%
#with open('test_pickle.pkl', 'wb') as pickle_out:
      #pickle.dump(df, pickle_out)

# %%
#conn = sqlite3.connect('orders.db')
